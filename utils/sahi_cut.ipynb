# %%
from sahi.slicing import slice_image

# %%
slice_image(
    image="uk_test_stitch.jpg",
    output_file_name="uk__test_stitch",
    output_dir="cut_uk__test_stitch",
    slice_height=1024,
    slice_width=1024,
    overlap_height_ratio=0.2,
    overlap_width_ratio=0.2
)
